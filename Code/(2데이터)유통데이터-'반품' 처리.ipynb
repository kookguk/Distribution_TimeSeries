# %% [markdown]
# ## 0. 1데이터 시트 합치기(기간 합치기)

# %%
import pandas as pd

# %%
file_path = '(2 데이터) 유통데이터 활용 경진대회 배포용.xlsx'

# 모든 시트 합치기
excel_file = pd.ExcelFile(file_path)
df = pd.concat([pd.read_excel(file_path, sheet_name=sheet) for sheet in excel_file.sheet_names])

df
# Out:
#               판매일  구분   우편번호   매출처코드  판매수량 옵션코드      규격  입수  상품 바코드(대한상의)  \
# 0      2021-01-31  매출  50868  202441     2   BX      10  10  7.880106e+13
# 1      2021-01-31  매출  51205  202520     1   BX  16(단종)  16  8.880106e+13
# 2      2021-01-31  매출  51174  200044     1   BX      24  24  1.880105e+13
# 3      2021-01-31  매출  51174  200044     1   BX      12  12  1.880105e+13
# 4      2021-01-31  매출  51170  200046     1   BX   10/20  20  1.880107e+13
# ...           ...  ..    ...     ...   ...  ...     ...  ..           ...
# 197868 2023-12-30  반품  51377  200068    10   EA       1   1  8.804341e+12
# 197869 2023-12-30  반품  51377  200068    10   EA     NaN   1  8.809014e+12
# 197870 2023-12-30  반품  51377  200068    12   EA   48/24   1  8.801046e+12
# 197871 2023-12-30  반품  51402  200002     1   EA       4   1  8.801034e+12
# 197872 2023-12-30  반품  51730  200673     5   EA   24/12   1  4.902430e+12
#
#                                  상품명       대분류      중분류       소분류  Unnamed: 13
# 0                 (롯데칠성)비타파워100ml*10     음료,차류       음료     기능성음료          NaN
# 1                (롯데제과)몽쉘크림케이크6입192g  빵.케익.과자류    빵.케익류      과자빵류          NaN
# 2                         (동원)꽁치300g      통조림류  기타병·통조림   기타병·통조림          NaN
# 3                 (오뚜기)열라면종이(용기)105g    면류.라면류      라면류      용기라면          NaN
# 4                       (삼양식품)사또밥67g  빵.케익.과자류      과자류       스낵류          NaN
# ...                              ...       ...      ...       ...          ...
# 197868                   크린공기(동양)150      기타잡화     기타잡화      기타잡화          NaN
# 197869                          예식장갑      생활잡화   기타생활잡화    기타생활잡화          NaN
# 197870         (애경)2080오리지날칫솔1입(탄력모)      일상용품     구강용품        치솔          NaN
# 197871  (정식품)베지밀5060시니어두유검은콩190ml*16      유제품류   우유.음용류       NaN          NaN
# 197872        (P&G)페브리즈은은한향(리필)320ml      일상용품     방향제류  기타방향용제품류          NaN
#
# [593150 rows x 14 columns]

# %% [markdown]
# ## 1. '반품' 행 처리 - 상품바코드별 계산

# %%
# '상품 바코드(대한상의)'로 그룹화하고 '판매수량'을 더함
df1 = df.groupby(['상품 바코드(대한상의)'], as_index=False).agg({
    '판매수량': 'sum',
    '판매일': 'first',   
    '구분': 'first',
    '우편번호': 'first',
    '매출처코드': 'first',
    '옵션코드': 'first',
    '규격': 'first',
    '입수': 'first',
    '상품명': 'first',
    '대분류': 'first',
    '중분류': 'first',
    '소분류': 'first'
})

df1
# Out:
#       상품 바코드(대한상의)  판매수량        판매일  구분   우편번호   매출처코드 옵션코드   규격  입수  \
# 0     2.351481e+07    25 2022-04-30  매출  51204  200235   EA    6   1
# 1     5.042642e+07    72 2022-04-30  매출  52009  200817   EA   72   1
# 2     8.005028e+07   109 2021-06-30  매출  51739  200231   EA   96   1
# 3     8.013591e+07   133 2021-01-31  매출  51167  201736   EA   48   1
# 4     8.017761e+07   239 2021-11-30  매출  51402  200002   EA  160   1
# ...            ...   ...        ...  ..    ...     ...  ...  ...  ..
# 8731  8.880112e+13    54 2021-03-31  매출  50430  202595  BX2   40  40
# 8732  8.880112e+13     5 2021-01-31  매출  42764  200318   CS   40  40
# 8733  8.880112e+13    18 2022-05-31  매출  34510  202440  BX4   24  24
# 8734  9.880106e+13    34 2021-01-31  매출  51402  200162   BX   24  24
# 8735  9.880112e+13     7 2021-04-30  매출  51199  201300  BX3   24  24
#
#                     상품명       대분류     중분류     소분류
# 0      대패삼겹살구이600g(미국산)      냉동냉장    축산식품    None
# 1         (로아커)키캣4핑거35g  빵.케익.과자류     과자류    초콜릿류
# 2            페레로로쉐(T-3)  빵.케익.과자류     과자류    초콜릿류
# 3            페레로로쉐(T-5)  빵.케익.과자류     과자류    초콜릿류
# 4         킨더초콜릿(T-4)50g  빵.케익.과자류     과자류    초콜릿류
# ...                 ...       ...     ...     ...
# 8731        (롯데)아맛나80ml      냉동냉장  아이스크림류  아이스크림류
# 8732           (롯데)초코퍼지      냉동냉장  아이스크림류  아이스크림류
# 8733   (롯데)구구콘스타초코160ml      냉동냉장  아이스크림류  아이스크림류
# 8734  (롯데)설레임밀크170ml(신)      냉동냉장  아이스크림류  아이스크림류
# 8735            (롯데)돼지콘      냉동냉장  아이스크림류  아이스크림류
#
# [8736 rows x 13 columns]

# %% [markdown]
# ## 2. '반품' 행 처리 - 판매일, 상품바코드별 계산

# %%
# '판매일'과 '상품 바코드(대한상의)'로 그룹화하고 '판매수량' 더하기
df2 = df.groupby(['판매일', '상품 바코드(대한상의)'], as_index=False).agg({
    '판매수량': 'sum',      
    '구분': 'first',
    '우편번호': 'first',
    '매출처코드': 'first',
    '옵션코드': 'first',
    '규격': 'first',
    '입수': 'first',
    '상품명': 'first',
    '대분류': 'first',
    '중분류': 'first',
    '소분류': 'first'
})

df2
# Out:
#               판매일  상품 바코드(대한상의)  판매수량  구분   우편번호   매출처코드 옵션코드    규격  입수  \
# 0      2021-01-31  8.013591e+07    13  매출  51167  201736   EA    48   1
# 1      2021-01-31  8.097448e+07     1  매출  51587  202449   EA    48   1
# 2      2021-01-31  3.400072e+10     1  매출  51575  202493   EA     4   1
# 3      2021-01-31  3.400072e+10     1  매출  51522  202574   CS    32   8
# 4      2021-01-31  4.168930e+10     8  매출  51174  202469   EA  None   1
# ...           ...           ...   ...  ..    ...     ...  ...   ...  ..
# 183067 2023-12-30  3.880105e+13     3  매출  51157  201575   CS    20  20
# 183068 2023-12-30  4.880124e+13    10  매출  51730  200673   CS     4   4
# 183069 2023-12-30  5.880106e+13     1  매출  51421  200342   CS  12/6   6
# 183070 2023-12-30  5.880106e+13     1  매출  51421  200342   CS  12/6   6
# 183071 2023-12-30  6.880106e+13     2  매출  51178  202466   CS    30  30
#
#                            상품명       대분류     중분류        소분류
# 0                   페레로로쉐(T-5)  빵.케익.과자류     과자류       초콜릿류
# 1                킨더조이(남아)1구20g  빵.케익.과자류     과자류       초콜릿류
# 2        (롯데제과)아이스브레이커스베리42g*8  빵.케익.과자류     과자류        캔디류
# 3          (롯데제과)아이스브레이커스민트42g  빵.케익.과자류     과자류        캔디류
# 4                         지프기름      생활잡화  기타생활잡화     기타생활잡화
# ...                        ...       ...     ...        ...
# 183067        (대상)순창양념쌈장사각500g      조미료류      장류         쌈장
# 183068  (모나리자)녹스점보롤220m*4롤(파랑)      일상용품    화장지류    두루마리화장지
# 183069          (델몬트)델몬트매실1.5L     음료,차류      음료  과즙·희석과즙음료
# 183070       (델몬트)델몬트망고스카시1.5L     음료,차류      음료  과즙·희석과즙음료
# 183071       (롯데칠성)레쓰비마일드175ml     음료,차류      음료        캔커피
#
# [183072 rows x 13 columns]

# %% [markdown]
# ## 3. '반품' 행 처리 - 단순 반품 행 제거

# %%
# '구분' 칼럼이 '반품'인 행을 제거
df3 = df[df['구분'] != '반품']

df3
# Out:
#               판매일  구분   우편번호   매출처코드  판매수량 옵션코드      규격  입수  상품 바코드(대한상의)  \
# 0      2021-01-31  매출  50868  202441     2   BX      10  10  7.880106e+13
# 1      2021-01-31  매출  51205  202520     1   BX  16(단종)  16  8.880106e+13
# 2      2021-01-31  매출  51174  200044     1   BX      24  24  1.880105e+13
# 3      2021-01-31  매출  51174  200044     1   BX      12  12  1.880105e+13
# 4      2021-01-31  매출  51170  200046     1   BX   10/20  20  1.880107e+13
# ...           ...  ..    ...     ...   ...  ...     ...  ..           ...
# 197810 2023-12-30  매출  51273  200350     5   EA       1   1  8.801308e+12
# 197811 2023-12-30  매출  51273  200350     7   EA      20   1  8.809315e+12
# 197812 2023-12-30  매출  51273  200350    10   EA      40   1  8.809015e+12
# 197813 2023-12-30  매출  51273  200350    20   EA      20   1  8.801097e+12
# 197814 2023-12-30  매출  51273  200350    30   EA      30   1  8.801095e+12
#
#                          상품명       대분류      중분류      소분류  Unnamed: 13
# 0         (롯데칠성)비타파워100ml*10     음료,차류       음료    기능성음료          NaN
# 1        (롯데제과)몽쉘크림케이크6입192g  빵.케익.과자류    빵.케익류     과자빵류          NaN
# 2                 (동원)꽁치300g      통조림류  기타병·통조림  기타병·통조림          NaN
# 3         (오뚜기)열라면종이(용기)105g    면류.라면류      라면류     용기라면          NaN
# 4               (삼양식품)사또밥67g  빵.케익.과자류      과자류      스낵류          NaN
# ...                      ...       ...      ...      ...          ...
# 197810             왕오징어구이22g     가공식품류     술안주류     술안주류          NaN
# 197811     (구룡)진짜쥐치포(20g*5입)     가공식품류     술안주류     술안주류          NaN
# 197812  (동서)단단하고향이좋은로즈비누150g      일상용품     위생용품     세안용품          NaN
# 197813    (동아오츠카)포카리스웨트500ml     음료,차류       음료    스포츠음료          NaN
# 197814    (코카콜라)조지아오리지널240ml     음료,차류       음료      캔커피          NaN
#
# [580952 rows x 14 columns]

# %%
df2.to_excel('데이터2_반품 처리.xlsx', index=False)
